# %%
# %load_ext sql

# %%
from pathlib import Path
import re

# %%
symbols = {}
for path in Path("../").iterdir():
    if path.is_dir() and re.match("^datadir" ,path.name):
        # %sql sqlite:///{path}/crawl-data.sqlite
        result = %sql SELECT DISTINCT(symbol) FROM javascript
        if result:
            for symbol in result.DataFrame()['symbol']:
                if symbol in symbols:
                    symbols[symbol].append(path.name)
                else:
                    symbols[symbol] = [path.name]
# Out:
#  * sqlite:///../datadir10000/crawl-data.sqlite
# Done.
#    sqlite:///../datadir10000/crawl-data.sqlite
#  * sqlite:///../datadirDemoSites/crawl-data.sqlite
# Done.
#  * sqlite:///../datadir/crawl-data.sqlite
#    sqlite:///../datadir10000/crawl-data.sqlite
#    sqlite:///../datadirDemoSites/crawl-data.sqlite
# Done.
#    sqlite:///../datadir/crawl-data.sqlite
#    sqlite:///../datadir10000/crawl-data.sqlite
#  * sqlite:///../datadir52fingerprinters/crawl-data.sqlite
#    sqlite:///../datadirDemoSites/crawl-data.sqlite
# Done.

# %%
import json
print( json.dumps( symbols, indent= 4 ) )
# Out:
# {
#     "window.navigator.userAgent": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.document.cookie": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.localStorage": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "Storage.getItem": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.product": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "Storage.setItem": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.sessionStorage": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.appName": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.document.referrer": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.onLine": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.cookieEnabled": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.languages": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.screen.colorDepth": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.doNotTrack": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.name": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.language": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.platform": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.javaEnabled": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "Storage.length": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "Storage.key": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.maxTouchPoints": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.getContext": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.plugins": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "Storage.removeItem": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.appVersion": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.vendor": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.webdriver": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.serviceWorker": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.sendBeacon": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.permissions": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.textBaseline": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.font": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.width": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.height": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.fillText": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.toDataURL": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.mimeTypes": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.classList": [
#         "datadir10000",
#         "datadir"
#     ],
#     "window.navigator.mediaCapabilities": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.mediaSession": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.hardwareConcurrency": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.appCodeName": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.storage": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.geolocation": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.productSub": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.credentials": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.mediaDevices": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.screen.pixelDepth": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.fillStyle": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.fillRect": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.vendorSub": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.buildID": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.oscpu": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.getImageData": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.style": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.strokeStyle": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.arc": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.stroke": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.rect": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.isPointInPath": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.globalCompositeOperation": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.fill": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.transferControlToOffscreen": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.registerProtocolHandler": [
#         "datadir10000",
#         "datadir"
#     ],
#     "Storage.hasOwnProperty": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.clipboard": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.nodeType": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.getAttribute": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.setAttribute": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.ownerDocument": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.parentNode": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.getRootNode": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.getElementsByTagName": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.nodeName": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.scale": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.tagName": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.firstChild": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.nextSibling": [
#         "datadir10000",
#         "datadir"
#     ],
#     "CanvasRenderingContext2D.measureText": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "OfflineAudioContext.createOscillator": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "OscillatorNode.type": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "OscillatorNode.frequency": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "OfflineAudioContext.createDynamicsCompressor": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "OscillatorNode.connect": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "OfflineAudioContext.destination": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "OscillatorNode.start": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "OfflineAudioContext.oncomplete": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "OfflineAudioContext.startRendering": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.rotate": [
#         "datadir10000",
#         "datadir"
#     ],
#     "CanvasRenderingContext2D.shadowBlur": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.shadowColor": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.locks": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.__proto__": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "OfflineAudioContext.currentTime": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.save": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.restore": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.children": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.childElementCount": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.textContent": [
#         "datadir10000",
#         "datadir"
#     ],
#     "OscillatorNode.disconnect": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.pdfViewerEnabled": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.onselectstart": [
#         "datadir10000",
#         "datadir"
#     ],
#     "CanvasRenderingContext2D.shadowOffsetX": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.shadowOffsetY": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.lineCap": [
#         "datadir10000",
#         "datadir"
#     ],
#     "CanvasRenderingContext2D.lineJoin": [
#         "datadir10000",
#         "datadir"
#     ],
#     "CanvasRenderingContext2D.miterLimit": [
#         "datadir10000",
#         "datadir"
#     ],
#     "CanvasRenderingContext2D.textAlign": [
#         "datadir10000",
#         "datadir"
#     ],
#     "CanvasRenderingContext2D.createLinearGradient": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.createRadialGradient": [
#         "datadir10000",
#         "datadir"
#     ],
#     "CanvasRenderingContext2D.bezierCurveTo": [
#         "datadir10000",
#         "datadir"
#     ],
#     "CanvasRenderingContext2D.strokeText": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.lineWidth": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.setLineDash": [
#         "datadir10000",
#         "datadir"
#     ],
#     "CanvasRenderingContext2D.lineDashOffset": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.previousSibling": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.attributes": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.namespaceURI": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.childNodes": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.className": [
#         "datadir10000",
#         "datadir"
#     ],
#     "Storage.toString": [
#         "datadir10000",
#         "datadir"
#     ],
#     "RTCPeerConnection.localDescription": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "RTCPeerConnection.remoteDescription": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "RTCPeerConnection.signalingState": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "RTCPeerConnection.iceGatheringState": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "RTCPeerConnection.idpLoginUrl": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "RTCPeerConnection.peerIdentity": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "RTCPeerConnection.onicecandidate": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.valueOf": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.toString": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "RTCPeerConnection.createDataChannel": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "RTCPeerConnection.createOffer": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "RTCPeerConnection.setLocalDescription": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "RTCPeerConnection.onicegatheringstatechange": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.hasOwnProperty": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.id": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.addEventListener": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.offsetParent": [
#         "datadir10000",
#         "datadir"
#     ],
#     "CanvasRenderingContext2D.clip": [
#         "datadir10000",
#         "datadir"
#     ],
#     "OfflineAudioContext.state": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir"
#     ],
#     "window.navigator.hasOwnProperty": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "CanvasRenderingContext2D.ellipse": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.hasOwnProperty": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.toBlob": [
#         "datadir10000",
#         "datadir"
#     ],
#     "window.navigator.__lookupGetter__": [
#         "datadir10000",
#         "datadir"
#     ],
#     "AudioContext.destination": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "AudioContext.sampleRate": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir"
#     ],
#     "CanvasRenderingContext2D.putImageData": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "Storage.clear": [
#         "datadir10000",
#         "datadir"
#     ],
#     "Storage.__proto__": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.cloneNode": [
#         "datadir10000",
#         "datadir"
#     ],
#     "RTCPeerConnection.getStats": [
#         "datadir10000",
#         "datadir"
#     ],
#     "RTCPeerConnection.addTransceiver": [
#         "datadir10000",
#         "datadir"
#     ],
#     "RTCPeerConnection.createAnswer": [
#         "datadir10000",
#         "datadir"
#     ],
#     "RTCPeerConnection.addEventListener": [
#         "datadir10000",
#         "datadir"
#     ],
#     "RTCPeerConnection.removeEventListener": [
#         "datadir10000",
#         "datadir"
#     ],
#     "RTCPeerConnection.setRemoteDescription": [
#         "datadir10000",
#         "datadir"
#     ],
#     "AudioContext.createMediaStreamDestination": [
#         "datadir10000",
#         "datadir"
#     ],
#     "RTCPeerConnection.addTrack": [
#         "datadir10000",
#         "datadir"
#     ],
#     "RTCPeerConnection.close": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "window.navigator.requestMediaKeySystemAccess": [
#         "datadir10000",
#         "datadir"
#     ],
#     "AudioContext.createOscillator": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "AudioContext.createAnalyser": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "AudioContext.createScriptProcessor": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "AudioContext.createGain": [
#         "datadir10000",
#         "datadirDemoSites",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "AudioContext.createDynamicsCompressor": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "GainNode.gain": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "AnalyserNode.connect": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "ScriptProcessorNode.connect": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "GainNode.connect": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "ScriptProcessorNode.onaudioprocess": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "AudioContext.listener": [
#         "datadir10000",
#         "datadir52fingerprinters"
#     ],
#     "AnalyserNode.fftSize": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "AnalyserNode.frequencyBinCount": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "AnalyserNode.maxDecibels": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "AnalyserNode.minDecibels": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "AnalyserNode.smoothingTimeConstant": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "AnalyserNode.channelCount": [
#         "datadir10000",
#         "datadir52fingerprinters"
#     ],
#     "AnalyserNode.channelCountMode": [
#         "datadir10000",
#         "datadir52fingerprinters"
#     ],
#     "AnalyserNode.channelInterpretation": [
#         "datadir10000",
#         "datadir52fingerprinters"
#     ],
#     "AnalyserNode.numberOfInputs": [
#         "datadir10000",
#         "datadir52fingerprinters"
#     ],
#     "AnalyserNode.numberOfOutputs": [
#         "datadir10000",
#         "datadir52fingerprinters"
#     ],
#     "AudioContext.decodeAudioData": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.getClientRects": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.getBoundingClientRect": [
#         "datadir10000",
#         "datadir"
#     ],
#     "CanvasRenderingContext2D.strokeRect": [
#         "datadir10000",
#         "datadir"
#     ],
#     "AudioContext.currentTime": [
#         "datadir10000",
#         "datadir"
#     ],
#     "AudioContext.state": [
#         "datadir10000",
#         "datadir"
#     ],
#     "RTCPeerConnection.addIceCandidate": [
#         "datadir10000",
#         "datadir"
#     ],
#     "Storage.valueOf": [
#         "datadir10000"
#     ],
#     "CanvasRenderingContext2D.mozImageSmoothingEnabled": [
#         "datadir10000"
#     ],
#     "CanvasRenderingContext2D.imageSmoothingEnabled": [
#         "datadir10000",
#         "datadir"
#     ],
#     "CanvasRenderingContext2D.arcTo": [
#         "datadir10000",
#         "datadir"
#     ],
#     "CanvasRenderingContext2D.createImageData": [
#         "datadir10000",
#         "datadir"
#     ],
#     "window.navigator.taintEnabled": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.hasAttribute": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.offsetWidth": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.offsetHeight": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.shadowRoot": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.append": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.previousElementSibling": [
#         "datadir10000"
#     ],
#     "OfflineAudioContext.createAnalyser": [
#         "datadir10000"
#     ],
#     "AnalyserNode.getFloatFrequencyData": [
#         "datadir10000"
#     ],
#     "AnalyserNode.disconnect": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.nextElementSibling": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.firstElementChild": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.valueOf": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.toString": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.removeAttribute": [
#         "datadir10000",
#         "datadir"
#     ],
#     "AudioContext.createBuffer": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.querySelector": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.clientWidth": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.clientHeight": [
#         "datadir10000",
#         "datadir"
#     ],
#     "CanvasRenderingContext2D.resetTransform": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.draggable": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.compareDocumentPosition": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.parentElement": [
#         "datadir10000",
#         "datadir"
#     ],
#     "OfflineAudioContext.sampleRate": [
#         "datadir10000"
#     ],
#     "OfflineAudioContext.createBuffer": [
#         "datadir10000"
#     ],
#     "CanvasRenderingContext2D.createPattern": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.hasAttributes": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.matches": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.offsetLeft": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.getElementsByClassName": [
#         "datadir10000",
#         "datadir"
#     ],
#     "RTCPeerConnection.toString": [
#         "datadir10000",
#         "datadir"
#     ],
#     "AudioContext.createMediaElementSource": [
#         "datadir10000"
#     ],
#     "AudioContext.createPanner": [
#         "datadir10000"
#     ],
#     "window.navigator.vibrate": [
#         "datadir10000"
#     ],
#     "AudioContext.createBufferSource": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.getAttributeNames": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.removeEventListener": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.scrollWidth": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.scrollHeight": [
#         "datadir10000"
#     ],
#     "OfflineAudioContext.createBiquadFilter": [
#         "datadir10000"
#     ],
#     "AnalyserNode.context": [
#         "datadir10000"
#     ],
#     "OfflineAudioContext.listener": [
#         "datadir10000"
#     ],
#     "OscillatorNode.detune": [
#         "datadir10000"
#     ],
#     "OfflineAudioContext.addEventListener": [
#         "datadir10000"
#     ],
#     "AnalyserNode.__defineGetter__": [
#         "datadir10000"
#     ],
#     "AnalyserNode.__defineSetter__": [
#         "datadir10000"
#     ],
#     "AnalyserNode.__lookupGetter__": [
#         "datadir10000"
#     ],
#     "AnalyserNode.__lookupSetter__": [
#         "datadir10000"
#     ],
#     "AnalyserNode.__proto__": [
#         "datadir10000"
#     ],
#     "AnalyserNode.addEventListener": [
#         "datadir10000"
#     ],
#     "AnalyserNode.dispatchEvent": [
#         "datadir10000"
#     ],
#     "AnalyserNode.getByteFrequencyData": [
#         "datadir10000"
#     ],
#     "AnalyserNode.getByteTimeDomainData": [
#         "datadir10000"
#     ],
#     "AnalyserNode.getFloatTimeDomainData": [
#         "datadir10000"
#     ],
#     "AnalyserNode.hasOwnProperty": [
#         "datadir10000"
#     ],
#     "AnalyserNode.isPrototypeOf": [
#         "datadir10000"
#     ],
#     "AnalyserNode.propertyIsEnumerable": [
#         "datadir10000"
#     ],
#     "AnalyserNode.removeEventListener": [
#         "datadir10000"
#     ],
#     "AnalyserNode.toLocaleString": [
#         "datadir10000"
#     ],
#     "AnalyserNode.toString": [
#         "datadir10000"
#     ],
#     "AnalyserNode.valueOf": [
#         "datadir10000"
#     ],
#     "CanvasRenderingContext2D.getLineDash": [
#         "datadir10000"
#     ],
#     "CanvasRenderingContext2D.isPointInStroke": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.ATTRIBUTE_NODE": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.CDATA_SECTION_NODE": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.COMMENT_NODE": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.DOCUMENT_FRAGMENT_NODE": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.DOCUMENT_NODE": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.DOCUMENT_POSITION_CONTAINED_BY": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.DOCUMENT_POSITION_CONTAINS": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.DOCUMENT_POSITION_DISCONNECTED": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.DOCUMENT_POSITION_FOLLOWING": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.DOCUMENT_POSITION_IMPLEMENTATION_SPECIFIC": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.DOCUMENT_POSITION_PRECEDING": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.DOCUMENT_TYPE_NODE": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.ELEMENT_NODE": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.ENTITY_NODE": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.ENTITY_REFERENCE_NODE": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.NOTATION_NODE": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.PROCESSING_INSTRUCTION_NODE": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.TEXT_NODE": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.__defineGetter__": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.__defineSetter__": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.__lookupGetter__": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.__lookupSetter__": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.__proto__": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.after": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.animate": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.appendChild": [
#         "datadir10000",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.attachInternals": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.attachShadow": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.before": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.blur": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.captureStream": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.click": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.closest": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.contains": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.dispatchEvent": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.focus": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.getAnimations": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.getAttributeNS": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.getAttributeNode": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.getAttributeNodeNS": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.getElementsByTagNameNS": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.hasAttributeNS": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.hasChildNodes": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.hasPointerCapture": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.insertAdjacentElement": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.insertAdjacentHTML": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.insertAdjacentText": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.insertBefore": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.isDefaultNamespace": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.isEqualNode": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.isPrototypeOf": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.isSameNode": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.lookupNamespaceURI": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.lookupPrefix": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.mozMatchesSelector": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.mozRequestFullScreen": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.normalize": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.onmouseenter": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.onmouseleave": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.prepend": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.propertyIsEnumerable": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.querySelectorAll": [
#         "datadir10000",
#         "datadir",
#         "datadir52fingerprinters"
#     ],
#     "HTMLCanvasElement.releaseCapture": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.releasePointerCapture": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.remove": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.removeAttributeNS": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.removeAttributeNode": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.removeChild": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.replaceChild": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.replaceChildren": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.replaceWith": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.requestFullscreen": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.requestPointerLock": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.scroll": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.scrollBy": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.scrollIntoView": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.scrollTo": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.setAttributeNS": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.setAttributeNode": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.setAttributeNodeNS": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.setCapture": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.setPointerCapture": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.toLocaleString": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.toggleAttribute": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.webkitMatchesSelector": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.lastChild": [
#         "datadir10000"
#     ],
#     "CanvasRenderingContext2D.mozCurrentTransform": [
#         "datadir10000"
#     ],
#     "CanvasRenderingContext2D.mozCurrentTransformInverse": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.constructor": [
#         "datadir10000",
#         "datadir"
#     ],
#     "HTMLCanvasElement.outerHTML": [
#         "datadir10000",
#         "datadir"
#     ],
#     "AudioContext.resume": [
#         "datadir10000"
#     ],
#     "OfflineAudioContext.createGain": [
#         "datadir10000"
#     ],
#     "OfflineAudioContext.length": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.localName": [
#         "datadir10000"
#     ],
#     "AudioContext.baseLatency": [
#         "datadir10000"
#     ],
#     "AudioContext.outputLatency": [
#         "datadir10000"
#     ],
#     "HTMLCanvasElement.dataset": [
#         "datadir10000",
#         "datadir"
#     ],
#     "OscillatorNode.stop": [
#         "datadir"
#     ],
#     "window.navigator.__defineGetter__": [
#         "datadir"
#     ],
#     "HTMLCanvasElement.innerText": [
#         "datadir"
#     ],
#     "CanvasRenderingContext2D.filter": [
#         "datadir"
#     ],
#     "HTMLCanvasElement.clientTop": [
#         "datadir"
#     ],
#     "HTMLCanvasElement.clientLeft": [
#         "datadir"
#     ],
#     "HTMLCanvasElement.nodeValue": [
#         "datadir"
#     ],
#     "AudioContext.close": [
#         "datadir"
#     ],
#     "HTMLCanvasElement.onmouseout": [
#         "datadir"
#     ],
#     "HTMLCanvasElement.onmousemove": [
#         "datadir"
#     ],
#     "HTMLCanvasElement.onmousedown": [
#         "datadir"
#     ],
#     "HTMLCanvasElement.onmouseup": [
#         "datadir"
#     ]
# }
