# %%
import plyvel

# %%
db = plyvel.DB('../datadirTESTING/leveldb')

# %%
for key, value in db:
    # key = bytes(key)
    # key =str(key, encoding="ascii")
    # key = bytes(key, 'utf-8').decode()
    # value = bytes(value).decode()
    print(key)
    print(value)
    print(len(key))
    print()
# Out:
# b'01960af7f94ce8d0a74cc7d542f2c145a8ae233ccae1c014b70290272510d820'
# b'\n      var browserTests = [\n      "audio",\n      "availableScreenResolution",\n      "canvas",\n      "colorDepth",\n      "cookies",\n      "cpuClass",\n      "deviceDpi",\n      "doNotTrack",\n      "indexedDb",\n      "installedFonts",\n      "language",\n      // "localIp",\n      "localStorage",\n      "pixelRatio",\n      "platform",\n      "plugins",\n      "processorCores",\n      "screenResolution",\n      "sessionStorage",\n      "timezoneOffset",\n      "touchSupport",\n      "userAgent",\n      "webGl",\n    ];\n\n    imprint.test(browserTests).then(function (val) {\n      console.log("FINGERPRINT",val);\n    });\n  '
# 64
#
# b'241b8b034bd2c680c7681a96bf718aee0f3a28673dd7f199445a511c938bc096'
# ...

# %%
print( db.get(b'6068f86ff5e6d3a3e100e95fd0ab03a5fb9ebfca9386b2c0ee131361a62526c2') )
# Out:
# None

# %%
# %load_ext sql

# %%
# %sql sqlite:///../datadirTESTING/crawl-data.sqlite
# Out:
# 'Connected: @../datadirTESTING/crawl-data.sqlite'

# %%
# %%sql
# SELECT *
# FROM javascript_files
# WHERE content_hash <> ""
# Out:
#  * sqlite:///../datadirTESTING/crawl-data.sqlite
# Done.
# [(5, 4248521827, 2373723750502158, '', 'https://fingerprint-static-demo.vercel.app/public/html/fingerprintjs.html', 'https://fingerprint-static-demo.vercel.app/public/html/fingerprintjs.html', '', '', '821ff7fe201e522cb0617f90d2835bf63b85bc31b1bc466027b0c96ce178be3e'),
#  (7, 4248521827, 4248156953936436, '', 'https://fingerprint-static-demo.vercel.app/public/html/clientjs.html', 'https://fingerprint-static-demo.vercel.app/public/html/clientjs.html', '', '', '52475154a82db559596dbd0b16bd62968a4a28954d81c0bcd1882c81cf6b6198'),
#  (9, 4248521827, 6317064880038036, '', 'https://fingerprint-static-demo.vercel.app/public/html/imprintjs.html', 'https://fingerprint-static-demo.vercel.app/public/html/imprintjs.html', '', '', '01960af7f94ce8d0a74cc7d542f2c145a8ae233ccae1c014b70290272510d820')]

# %%
# %%sql
# SELECT *
# FROM http_responses
# WHERE content_hash <> ""
# Out:
#  * sqlite:///../datadirTESTING/crawl-data.sqlite
# Done.
# [(2, 0, 4248521827, 6333933682327349, '4ac73667-f63e-4f76-9f0a-57fdb01c5b48', 3, 1, 1, 0, 'https://fingerprint-react-demo.vercel.app/static/js/main.88a33984.js', 'GET', 200, 'HTTP/2.0 200 OK', 0, '[["access-control-allow-origin","*"],["age","3695"],["cache-control","s-maxage=31536000, immutable"],["content-disposition","inline; filename=\\"main ... (253 characters truncated) ... 3072000; includeSubDomains; preload"],["x-vercel-cache","HIT"],["x-vercel-id","iad1:iad1::p2kf5-1669913231023-7e4235cd3e74"],["X-Firefox-Spdy","h2"]]', 91, '', '2022-12-01T16:47:11.053Z', '2f67617dc38f5c1b60e7960e3b2492877cc3ce4d156d32fee18d5acbe6d12c9f'),
# ...

# %%
# %%sql
# SELECT *
# FROM javascript
# Out:
#  * sqlite:///../datadirTESTING/crawl-data.sqlite
# Done.
# [(1, 0, 4248521827, 6333933682327349, '4ac73667-f63e-4f76-9f0a-57fdb01c5b48', 8, 0, 1, 1, 0, 'https://fingerprint-react-demo.vercel.app/static/js/main.88a33984.js', '2', '239895', 'vt', '', 'https://fingerprint-react-demo.vercel.app/fingerprintjs', 'https://fingerprint-react-demo.vercel.app/fingerprintjs', '', 'window.navigator.vendor', 'get', '', None, '2022-12-01T16:47:11.500Z'),
#  (2, 0, 4248521827, 6333933682327349, '4ac73667-f63e-4f76-9f0a-57fdb01c5b48', 9, 1, 1, 1, 0, 'https://fingerprint-react-demo.vercel.app/static/js/main.88a33984.js', '2', '239642', 'mt', '', 'https://fingerprint-react-demo.vercel.app/fingerprintjs', 'https://fingerprint-react-demo.vercel.app/fingerprintjs', '', 'window.navigator.vendor', 'get', '', None, '2022-12-01T16:47:11.520Z'),
# ...
